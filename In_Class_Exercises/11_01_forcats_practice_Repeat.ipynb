# %% [markdown]
# Re-create the following figure using the `mpg` data set.

# %% [markdown]
# <img src="figs/example.png" style="width: 600px;" />

# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Hints:
# - you can make a table with median values using `group_by` and `summarize`
# - use `geom_crossbar` to create the vertical line for median values
# - use `fct_reorder` to set the levels for `class`

# %%
mpg %>% head
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
# median_mpg = 
mpg %>%
                group_by(class) %>%
                          summarize(cty = median(cty)) %>%
                                fct_order(cty)
#             summarize(median_cty = median(cty))

#I think in class the key was that we wanted the median points to overlap with the standard graph and in 
# order to do that we need to have the same axis labels

#So I am going to re-do the above code but instead of median_cty, I am just going to leave it as cty
# Out:
# Error in fct_order(., cty): could not find function "fct_order"
# Traceback:
#
# 1. mpg %>% group_by(class) %>% summarize(cty = median(cty)) %>%
#  .     fct_order(cty)

# %%
p = ggplot(median_mpg, aes(x = cty, y = class))

p = p + geom_crossbar(data = median_mpg, mapping = aes(xmin = cty, xmax = cty), color = 'blue')

p
# Out:
# plot without title

# %% [markdown]
# ### Now to add the scatterplot on top of this, also keep in mind that we need to change the class variable to a factor so that we can arrange the categories
