# %% [markdown]
# Load the 📊`tidyverse`, 🐧`palmerpengions`, and ⚖`scales` packages.

# %%
library('tidyverse')
library('palmerpenguins')
library('scales')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor

# %%
penguins %>% head
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
options(repr.plot.height = 5, repr.plot.width = 7, repr.plot.res = 250)

p = ggplot(penguins, aes(x = body_mass_g, color = species, fill = species))

p = p + geom_density(alpha = 0.2) + geom_rug() # each tick mark represents one of the penguins

p = p + scale_fill_brewer(type = "qual", palette = "Set2") #3 functions in R *Important* - geom, scale, theme

p = p + scale_color_brewer(type = "qual", palette = "Set2")

p = p + theme_minimal()

p = p + labs(x = 'Body mass in grams', y = 'Density') # I want to set color = 'Species' but it creates two..

p = p + theme(legend.position = 'top', legend.justification = 'left')

p = p + scale_x_continuous(labels = comma)

p
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (stat_density).”
# plot without title

# %% [markdown]
# Use `geom_density` to create the following figure from the `penguins` data.
#
# <img src="https://raw.githubusercontent.com/chuckpr/BIOS512/main/in-class-exercises/07/palmer-kde.png"
#      style="width: 700px;" />

# %% [markdown]
# 🛑 **STOP HERE** 🛑

# %% [markdown]
# What columns do we need to make the **ECDF** equivalent of the above chart using `geom_point` + `geom_line`?

# %% [markdown]
# We need a column for the rel_position of the points (range from 0 to 1) and then a column for body_mass, and then a oclumn for color = species

# %% [markdown]
# Read the following code snippet. Can you make sense of what it's doing? What do you think the output will be?
#
# ```R
# ecdf = penguins %>%
#     arrange(body_mass_g) %>%
#     group_by(species) %>%
#     mutate(rn = row_number(), fraction_of_penguins = rn / max(rn))
# ```

# %% [markdown]
# Copy the snippet above and execute it. What's does the `ecdf` table look like?

# %%
ecdf = penguins %>%
    arrange(body_mass_g) %>%
    group_by(species) %>%
    mutate(rn = row_number(), fraction_of_penguins = rn / max(rn)) # mutate adds a column to our data set

# %% [markdown]
# Using the `ecdf` table, create an **ECDF** chart of penguin body mass grouped by species.

# %%
penguins %>%  arrange(body_mass_g) %>% group_by(species) %>% mutate(rn = row_number(), fraction_of_penguins = rn / max(rn))
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Chinstrap Dream     46.9           16.6          192
# 2   Adelie    Biscoe    36.5           16.6          181
# 3   Adelie    Biscoe    36.4           17.1          184
# 4   Adelie    Biscoe    34.5           18.1          187
# 5   Adelie    Dream     33.1           16.1          178
# 6   Adelie    Torgersen 38.6           17.0          188
# 7   Chinstrap Dream     43.2           16.6          187
# 8   Adelie    Biscoe    37.9           18.6          193
# 9   Adelie    Dream     37.5           18.9          179
# 10  Adelie    Dream     37.0           16.9          185
# 11  Adelie    Dream     37.3           16.8          192
# 12  Adelie    Torgersen 35.9           16.6          190
# 13  Adelie    Torgersen 35.2           15.9          186
# 14  Adelie    Torgersen 39.0           17.1          191
# 15  Adelie    Dream     32.1           15.5          188
# 11  3000        female 2009  9  0.059210526
# 12  3050        female 2008 10  0.065789474
# 13  3050        female 2009 11  0.072368421
# 14  3050        female 2009 12  0.078947368
# 15  3050        female 2009 13  0.085526316
# 16  3075        female 2009 14  0.092105263
# 17  3100        female 2007 15  0.098684211
# 18  3150        female 2007 16  0.105263158
# 19  3150        female 2007 17  0.111842105
# 20  3150        female 2008 18  0.118421053
# 21  3150        female 2009 19  0.125000000
# 22  3175        female 2009 20  0.131578947
# 23  3175        female 2009 21  0.138157895
# 24  3200        female 2007 22  0.144736842
# 25  3200        female 2007 23  0.151315789
# 26  3200        female 2008 24  0.157894737
# 27  3200        female 2009 25  0.164473684
# 28  3200        female 2008  3  0.044117647
# 29  3250        female 2007 26  0.171052632
# 30  3250        female 2007 27  0.177631579
# ⋮   ⋮           ⋮      ⋮    ⋮   ⋮
# 315 5550        male   2007  96 0.7741935
# 316 5550        male   2007  97 0.7822581
# 317 5550        male   2008  98 0.7903226
# 318 5550        male   2008  99 0.7983871
# 319 5550        male   2008 100 0.8064516
# 320 5550        male   2009 101 0.8145161
# 321 5600        male   2009 102 0.8225806
# 322 5600        male   2009 103 0.8306452
# 323 5650        male   2007 104 0.8387097
# 324 5650        male   2008 105 0.8467742
# 325 5650        male   2009 106 0.8548387
# 326 5700        male   2007 107 0.8629032
# 327 5700        male   2007 108 0.8709677
# 328 5700        male   2007 109 0.8790323
# 329 5700        male   2008 110 0.8870968
# 330 5700        male   2008 111 0.8951613
# 331 5750        male   2009 112 0.9032258
# 332 5800        male   2008 113 0.9112903
# 333 5800        male   2008 114 0.9193548
# 334 5850        male   2007 115 0.9274194
# 335 5850        male   2007 116 0.9354839
# 336 5850        male   2009 117 0.9435484
# 337 5950        male   2008 118 0.9516129
# 338 5950        male   2009 119 0.9596774
# 339 6000        male   2008 120 0.9677419
# 340 6000        male   2009 121 0.9758065
# 341 6050        male   2007 122 0.9838710
# 342 6300        male   2007 123 0.9919355
# 343   NA        NA     2007 152 1.0000000
# 344   NA        NA     2009 124 1.0000000

# %%
options(repr.plot.height = 6, repr.plot.width = 10, repr.plot.res = 250)


p = ggplot(ecdf, aes(x = body_mass_g, y = fraction_of_penguins, color = species))

# p = p + geom_line()

p = p + geom_point() + geom_step()

p = p + scale_color_brewer(type = "qual", palette = "Set2")

p = p + theme_minimal()

p = p + labs(x = 'Body mass in grams', y = 'Percent of Penguins') # I want to set color = 'Species' but it creates two..

p = p + scale_x_continuous(labels = comma)

p
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_point).”
# Warning message:
# “Removed 2 row(s) containing missing values (geom_path).”
# plot without title

# %% [markdown]
# Uncomment the code below, change the cell to markdown and execute if you want to see my solution.

# %% [markdown]
# ![](https://raw.githubusercontent.com/chuckpr/BIOS512/main/in-class-exercises/07/palmer-ecdf.png)
