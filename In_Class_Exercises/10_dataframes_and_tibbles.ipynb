# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Previewing

# %%
iris %>% head
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
# iris %>% print

# %%
iris %>% as_tibble %>% print #use print (n = 5) only print 5 rows, you can also do print(n=5, width = 1) this changes the number of columns that are printed but this does not actually mean the number of columns
                             # width is the number of characters | width = Inf let's you see everything
# Out:
# # A tibble: 150 × 5
#    Sepal.Length Sepal.Width Petal.Length Petal.Width Species
#           <dbl>       <dbl>        <dbl>       <dbl> <fct>
#  1          5.1         3.5          1.4         0.2 setosa
#  2          4.9         3            1.4         0.2 setosa
#  3          4.7         3.2          1.3         0.2 setosa
#  4          4.6         3.1          1.5         0.2 setosa
#  5          5           3.6          1.4         0.2 setosa
#  6          5.4         3.9          1.7         0.4 setosa
#  7          4.6         3.4          1.4         0.3 setosa
#  8          5           3.4          1.5         0.2 setosa
#  9          4.4         2.9          1.4         0.2 setosa
# 10          4.9         3.1          1.5         0.1 setosa
# # … with 140 more rows

# %% [markdown]
# # Pulling out a column

# %%
# iris$Sepal.Length

# %%
iris.tibble = iris %>% as_tibble

# iris.tibble$Sepal.Length

# %%
# iris.tibble %>% pull(Sepal.Length)

# %%
iris %>% pull(Species) %>% table() #This prints the number in each category within a variable
# Out:
# .
#     setosa versicolor  virginica
#         50         50         50

# %% [markdown]
# # Unconventional column names

# %%
iris.tibble  = iris.tibble %>% mutate(`1` = 'a') #Unconventional column names need to be wrapped in backticks ``
print(iris.tibble)
# Out:
# # A tibble: 150 × 6
#    Sepal.Length Sepal.Width Petal.Length Petal.Width Species `1`
#           <dbl>       <dbl>        <dbl>       <dbl> <fct>   <chr>
#  1          5.1         3.5          1.4         0.2 setosa  a
#  2          4.9         3            1.4         0.2 setosa  a
#  3          4.7         3.2          1.3         0.2 setosa  a
#  4          4.6         3.1          1.5         0.2 setosa  a
#  5          5           3.6          1.4         0.2 setosa  a
#  6          5.4         3.9          1.7         0.4 setosa  a
#  7          4.6         3.4          1.4         0.3 setosa  a
#  8          5           3.4          1.5         0.2 setosa  a
#  9          4.4         2.9          1.4         0.2 setosa  a
# 10          4.9         3.1          1.5         0.1 setosa  a
# # … with 140 more rows

# %%
iris.tibble %>% pull(`1`)
# Out:
#   [1] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
#  [19] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
#  [37] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
#  [55] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
#  [73] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
#  [91] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
# [109] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
# [127] "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a" "a"
# [145] "a" "a" "a" "a" "a" "a"
